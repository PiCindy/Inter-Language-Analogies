# %%
import nlg
from nlg.Vector.Vectors import Vectors

# %%
def create_vectors(file):
    sigmorphon_lines = [line.strip() for line in open(file)]
        
    char_feature = True
    morph_feature = True
    lemma_feature = False
    gen_lemma = False

    sigmorphon_vectors = Vectors.fromSigmorphonFile(lines=sigmorphon_lines,
                                char_feature=char_feature,
                                morph_feature=morph_feature,
                                lemma_feature=lemma_feature,
                                gen_lemma=gen_lemma)
    
    return sigmorphon_vectors

# %%
def create_file(file, vectors):
    open(file, 'w').close()
    with open(file, 'w') as f:
        for vector in vectors:
            f.write(vector)
            f.write('\n')

# %%
sig_file = 'task0-data/DEVELOPMENT-LANGUAGES/austronesian/tgl.dev'
vec_file = 'data/tgl.vec'
vectors = create_vectors(sig_file)
create_file(vec_file, vectors)
# !python3 Lines2Vectors.py <'data/tgl.vec' -V | python3 Vectors2Grids.py -V
# Out:
# # Reading file...
# # Number of lines read: 236
# # Building vector with feature...
# #	- char : True
# #	- token: False
# #	- morph: False
# #	- lemma: False
# # Alphabet size: 26
# # Lines2Vectors.py - Processing time: 0:00:00
# # Alphabet size: 26
# # Morph feature size: 14
# # Reading words and their vector representations...
# # Clustering the words according to their feature vectors...
# #	- min cluster size: 2
# #	- max cluster size: None
# # Add the indistinguishables...
# # Checking distance constraints...
# # Building grids...
# #	- saturation ≥ 0.000
# #	- cluster size ≥ 3
# ása : umása :: lapit : lumapit :: pipirma : pumipirma :: hihiram : humihiram :: dadampot : dumadampot
# nag-iipon : nagdaramdám :: mag-iipon : magdaramdám
# inulat : inusog :: iuulat : iuusog
# iniilawan : iilaw :: nililigawan : liligaw
# aásahan : pinapasan :: inásahan : pinapansin
#
# # Vectors2Grids.py - Processing time: 0:00:00

# %%
sig_file = 'task0-data/DEVELOPMENT-LANGUAGES/austronesian/ceb.dev'
vec_file = 'data/ceb.vec'
vectors = create_vectors(sig_file)
create_file(vec_file, vectors)
# !python3 Lines2Vectors.py <'data/ceb.vec' -V | python3 Vectors2Grids.py -V
# Out:
# # Reading file...
# # Number of lines read: 55
# # Building vector with feature...
# #	- char : True
# #	- token: False
# #	- morph: False
# #	- lemma: False
# # Alphabet size: 20
# # Lines2Vectors.py - Processing time: 0:00:00
# # Alphabet size: 20
# # Morph feature size: 12
# # Reading words and their vector representations...
# # Clustering the words according to their feature vectors...
# #	- min cluster size: 2
# #	- max cluster size: None
# # Add the indistinguishables...
# # Checking distance constraints...
# # Building grids...
# #	- saturation ≥ 0.000
# #	- cluster size ≥ 3
# ningkaon : ningbarog :: nakakaon : nakabarog
# moangkon : momaneho :: naangkon : namaneho
# nitudlo : ningtudlo :: nikuha : ningkuha :: nibarog : ningbarog
# ningduwa : moduwa :: ningbarog : mobarog
#
# # Vectors2Grids.py - Processing time: 0:00:00

# %%
sig_file = 'task0-data/DEVELOPMENT-LANGUAGES/austronesian/hil.dev'
vec_file = 'data/hil.vec'
vectors = create_vectors(sig_file)
create_file(vec_file, vectors)
# !python3 Lines2Vectors.py <'data/hil.vec' -V | python3 Vectors2Grids.py -V > 'data/hil.grid'
# Out:
# # Reading file...
# # Number of lines read: 110
# # Building vector with feature...
# #	- char : True
# #	- token: False
# #	- morph: False
# #	- lemma: False
# # Alphabet size: 21
# # Lines2Vectors.py - Processing time: 0:00:00
# # Alphabet size: 21
# # Morph feature size: 13
# # Reading words and their vector representations...
# # Clustering the words according to their feature vectors...
# #	- min cluster size: 2
# #	- max cluster size: None
# # Add the indistinguishables...
# # Checking distance constraints...
# # Building grids...
# #	- saturation ≥ 0.000
# #	- cluster size ≥ 3
# # Vectors2Grids.py - Processing time: 0:00:00

# %%
sig_file = 'task0-data/DEVELOPMENT-LANGUAGES/oto-manguean/azg.dev'
vec_file = 'data/azg.vec'
vectors = create_vectors(sig_file)
create_file(vec_file, vectors)
# !python3 Lines2Vectors.py <'data/azg.vec' -V | python3 Vectors2Grids.py -V
# Out:
# # Reading file...
# # Number of lines read: 1186
# # Building vector with feature...
# #	- char : True
# #	- token: False
# #	- morph: False
# #	- lemma: False
# # Alphabet size: 47
# # Alphabet size: 47
# # Morph feature size: 22
# # Reading words and their vector representations...
# # Lines2Vectors.py - Processing time: 0:00:00
# # Clustering the words according to their feature vectors...
# #	- min cluster size: 2
# #	- max cluster size: None
# # Add the indistinguishables...
# # Checking distance constraints...
# # Building grids...
# #	- saturation ≥ 0.000
# #	- cluster size ≥ 3
# n⁵ngo³tyèn¹há⁵á⁵ : tyèn¹há⁵á⁵ :: n⁵ngo³tyionʔ⁵³na³ki³ndyaʔ³nchhi⁵³ : tyionʔ⁵³na³ki³ndyaʔ³nchhi⁵³ :: n⁵ngo³tyiɔn⁵³hndyè¹nɔ⁵³ : tyiɔn⁵³hndyè¹nɔ⁵³ :: n⁵ngo³ki³ndyiʔ³⁴ : ki³ndyiʔ³⁴
# ko³tuèʔ¹ʔu³ : ko³tyion³oʔ³na³ki³ndyaʔ³ngiò¹oʔ³ : ko³tyiô³¹xhò¹ : ko³ndye¹²tzìʔ¹nʔòʔ¹ : ko³tiu³oʔ³ :: ki³tuèʔ¹ʔu³ : ki³tyion³oʔ³na³ki³ndyaʔ³ngiò¹oʔ³ : ki³tyiô³¹xhò¹ : ki³ndye¹²tzìʔ¹nʔòʔ¹ : ki³tiu³oʔ³
# ...
